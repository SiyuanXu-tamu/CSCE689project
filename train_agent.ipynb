# %%
import os, sys
sys.path.append('.')
sys.path.append('./game')
sys.path.append('./agents')
sys.path.append('./utils')
import argparse

from BaselineAgent import BaselineAgent
from QLearningAgent import QLearningAgent
from SARSAAgent import SARSAAgent
from FuncApproxLRAgent import FuncApproxLRAgent
from FuncApproxCNNAgent import FuncApproxCNNAgent
from FuncApproxDNNAgent import FuncApproxDNNAgent

import warnings
warnings.filterwarnings('ignore')


agent_options = ['QLearning', 'SARSA']
order_options = ['forward', 'backward']

agrnt_choice = 'QLearning'  ###you can choice the one you like
order_chice = 'backward'  ###foward Q-learning or backward Q-learning
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.6.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
def parseArgs():
    ''' Reads command line arguments. '''
    parser = argparse.ArgumentParser(description = 'An AI Agent for Flappy Bird.',
                                     formatter_class = argparse.ArgumentDefaultsHelpFormatter)

    parser.add_argument('--algo', type = str, default = agrnt_choice,
                        help = 'Learning algorithm.', choices = agent_options)
    
    # Parameters for Q-learning
    parser.add_argument('--rounding', type = int, default = 10, #None,
                        help = 'Level of discretization.')
    parser.add_argument('--probFlap', type = float, default = 0.1,
                        help = 'Probability of flappingin epsilon-greedy policy.')
    parser.add_argument('--order', type = str, default = order_chice,
                        choices = order_options, help = 'Order of Q-value updates.')
    parser.add_argument('--discount', type = float, default = 1.,
                        help = 'Discount factor.')
    parser.add_argument('--numTrainIters', type = int, default = 10000,
                        help = 'Number of training iterations.')
    parser.add_argument('--numTestIters', type = int, default = 1000,
                        help = 'Number of testing iterations.')
    parser.add_argument('--evalPerIters', type = int, default = 250,
                        help = 'Frequency of running evaluation.')
    parser.add_argument('--epsilon', type = float, default = 0.,
                        help = 'Epsilon-greedy policy.')
    parser.add_argument('--lr', type = float, default = 0.8,#0.1
                        help = 'Learning rate.')
    parser.add_argument('--epsilonDecay', action = 'store_true',
                        help = 'Use epsilon decay or not.')
    parser.add_argument('--lrDecay', action = 'store_true',
                        help = 'Use learning rate decay or not.')
    
    # Additional Parameters for Neural Networks.
    parser.add_argument('--resume', action = 'store_true',
                        help = 'Resume from checkpoints or not.')
    parser.add_argument('--seed', type = int, default = 0,
                        help = 'Random seed for PyTorch.')
    parser.add_argument('--batch-size', type = int, default = 32,
                        help = 'Size of a training minibatch.')
    parser.add_argument('--num-experience', type = int, default = 50000,
                        help = 'Number of past experiences stored in the memory.')
    
    args = parser.parse_known_args(args=[])[0]
    return args

    
def main():
    ''' Main program. '''
    print("Welcome to Flappy Bird.")
    args = parseArgs()
          
    if args.algo == 'QLearning':
        agent = QLearningAgent(actions = [0, 1], rounding = args.rounding, probFlap = args.probFlap)
        agent.train(order = args.order, numIters = args.numTrainIters, epsilon = args.epsilon,
                    discount = args.discount, eta = args.lr, epsilonDecay = args.epsilonDecay,
                    etaDecay = args.lrDecay, evalPerIters = args.evalPerIters,
                    numItersEval = args.numTestIters)
        agent.saveQValues()
        
    elif args.algo == 'SARSA':
        agent = SARSAAgent(actions = [0, 1], rounding = args.rounding, probFlap = args.probFlap)
        agent.train(order = args.order, numIters = args.numTrainIters, epsilon = args.epsilon,
                    discount = args.discount, eta = args.lr, epsilonDecay = args.epsilonDecay,
                    etaDecay = args.lrDecay, evalPerIters = args.evalPerIters,
                    numItersEval = args.numTestIters)
        agent.saveQValues()
               
if __name__ == '__main__':
    main()
# Out:
# Welcome to Flappy Bird.
# Iter:  0
# Iter:  50
# Iter:  100
# Iter:  150
# Iter:  200
# Max Score Test:  2
# Max Reward Test:  0
#
# Iter:  250
# Iter:  300
# Iter:  350
# Iter:  400
# Iter:  450
# Max Score Test:  3
# Max Reward Test:  0
#
# Iter:  500
# Iter:  550
# Iter:  600
# Iter:  650
# Iter:  700
# Max Score Test:  4
# Max Reward Test:  0
#
# Iter:  750
# Iter:  800
# Iter:  850
# Iter:  900
# Iter:  950
# Max Score Test:  7
# Max Reward Test:  0
#
# Iter:  1000
# Iter:  1050
# Iter:  1100
# Iter:  1150
# Iter:  1200
# Max Score Test:  8
# Max Reward Test:  0
#
# Iter:  1250
# Iter:  1300
# Iter:  1350
# Iter:  1400
# Iter:  1450
# Max Score Test:  13
# Max Reward Test:  0
#
# Iter:  1500
# Iter:  1550
# Iter:  1600
# Iter:  1650
# Iter:  1700
# Max Score Test:  18
# Max Reward Test:  0
#
# Iter:  1750
# Iter:  1800
# Iter:  1850
# Iter:  1900
# Iter:  1950
# Max Score Test:  34
# Max Reward Test:  0
#
# Iter:  2000
# Iter:  2050
# Iter:  2100
# Iter:  2150
# Iter:  2200
# Max Score Test:  24
# Max Reward Test:  0
#
# Iter:  2250
# Iter:  2300
# Iter:  2350
# Iter:  2400
# Iter:  2450
# Max Score Test:  64
# Max Reward Test:  523.0
#
# Iter:  2500
# Iter:  2550
# Iter:  2600
# Iter:  2650
# Iter:  2700
# Max Score Test:  59
# Max Reward Test:  405.5
#
# Iter:  2750
# Iter:  2800
# Iter:  2850
# Iter:  2900
# Iter:  2950
# Max Score Test:  73
# Max Reward Test:  733.0
#
# Iter:  3000
# Iter:  3050
# Iter:  3100
# Iter:  3150
# Iter:  3200
# Max Score Test:  95
# Max Reward Test:  1245.5
#
# Iter:  3250
# Iter:  3300
# Iter:  3350
# Iter:  3400
# Iter:  3450
# Max Score Test:  111
# Max Reward Test:  1620.5
#
# Iter:  3500
# Iter:  3550
# Iter:  3600
# Iter:  3650
# Iter:  3700
# Max Score Test:  81
# Max Reward Test:  920.5
#
# Iter:  3750
# Iter:  3800
# Iter:  3850
# Iter:  3900
# Iter:  3950
# Max Score Test:  102
# Max Reward Test:  1410.5
#
# Iter:  4000
# Iter:  4050
# Iter:  4100
# Iter:  4150
# Iter:  4200
# Max Score Test:  61
# Max Reward Test:  453.0
#
# Iter:  4250
# Iter:  4300
# Iter:  4350
# Iter:  4400
# Iter:  4450
# Max Score Test:  202
# Max Reward Test:  3743.0
#
# Iter:  4500
# Iter:  4550
# Iter:  4600
# Iter:  4650
# Iter:  4700
# Max Score Test:  219
# Max Reward Test:  4140.5
#
# Iter:  4750
# Iter:  4800
# Iter:  4850
# Iter:  4900
# Iter:  4950
# Max Score Test:  82
# Max Reward Test:  943.0
#
# Iter:  5000
# Iter:  5050
# Iter:  5100
# Iter:  5150
# Iter:  5200
# Max Score Test:  184
# Max Reward Test:  3323.0
#
# Iter:  5250
# Iter:  5300
# Iter:  5350
# Iter:  5400
# Iter:  5450
# Max Score Test:  281
# Max Reward Test:  5585.5
#
# Iter:  5500
# Iter:  5550
# Iter:  5600
# Iter:  5650
# Iter:  5700
# Max Score Test:  470
# Max Reward Test:  9995.5
#
# Iter:  5750
# Iter:  5800
# Iter:  5850
# Iter:  5900
# Iter:  5950
# Max Score Test:  223
# Max Reward Test:  4233.0
#
# Iter:  6000
# Iter:  6050
# Iter:  6100
# Iter:  6150
# Iter:  6200
# Max Score Test:  424
# Max Reward Test:  8923.0
#
# Iter:  6250
# Iter:  6300
# Iter:  6350
# Iter:  6400
# Iter:  6450
# Max Score Test:  418
# Max Reward Test:  8783.0
#
# Iter:  6500
# Iter:  6550
# Iter:  6600
# Iter:  6650
# Iter:  6700
# Max Score Test:  518
# Max Reward Test:  11115.5
#
# Iter:  6750
# Iter:  6800
# Iter:  6850
# Iter:  6900
# Iter:  6950
# Max Score Test:  267
# Max Reward Test:  5260.5
#
# Iter:  7000
# Iter:  7050
# Iter:  7100
# Iter:  7150
# Iter:  7200
# Max Score Test:  429
# Max Reward Test:  9040.5
#
# Iter:  7250
# Iter:  7300
# Iter:  7350
# Iter:  7400
# Iter:  7450
# Max Score Test:  695
# Max Reward Test:  15245.5
#
# Iter:  7500
# Iter:  7550
# Iter:  7600
# Iter:  7650
# Iter:  7700
# Max Score Test:  407
# Max Reward Test:  8525.5
#
# Iter:  7750
# Iter:  7800
# Iter:  7850
# Iter:  7900
# Iter:  7950
# Max Score Test:  404
# Max Reward Test:  8455.5
#
# Iter:  8000
# Iter:  8050
# Iter:  8100
# Iter:  8150
# Iter:  8200
# Max Score Test:  250
# Max Reward Test:  4863.0
#
# Iter:  8250
# Iter:  8300
# Iter:  8350
# Iter:  8400
# Iter:  8450
# Max Score Test:  301
# Max Reward Test:  6053.0
#
# Iter:  8500
# Iter:  8550
# Iter:  8600
# Iter:  8650
# Iter:  8700
# Max Score Test:  145
# Max Reward Test:  2409.0
#
# Iter:  8750
# Iter:  8800
# Iter:  8850
# Iter:  8900
# Iter:  8950
# Max Score Test:  365
# Max Reward Test:  7545.5
#
# Iter:  9000
# Iter:  9050
# Iter:  9100
# Iter:  9150
# Iter:  9200
# Max Score Test:  623
# Max Reward Test:  13565.5
#
# Iter:  9250
# Iter:  9300
# Iter:  9350
# Iter:  9400
# Iter:  9450
# Max Score Test:  374
# Max Reward Test:  7755.5
#
# Iter:  9500
# Iter:  9550
# Iter:  9600
# Iter:  9650
# Iter:  9700
# Max Score Test:  641
# Max Reward Test:  13985.5
#
# Iter:  9750
# Iter:  9800
# Iter:  9850
# Iter:  9900
# Iter:  9950
# Iter:  9999
# Max Score Test:  376
# Max Reward Test:  7803.0
#
# Max Score Train:  550
# Max Reward Train:  11863.0
